# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import json 
from fredapi import Fred
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'notebook'  
pio.renderers.default = 'iframe'

# %%
with open('config.json') as config_file:
    config = json.load(config_file)

# %%
secret_key = config['SECRET_KEY']

# %% [markdown]
# # 1. create fred object

# %%
fred = Fred(api_key=secret_key)

# %% [markdown]
# # 2. search for economic data!

# %%
sp_search = fred.search('S&P', order_by='popularity')

# %%
sp_search
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2024-10-21   2024-10-21
# CSUSHPINSA              CSUSHPINSA     2024-10-21   2024-10-21
# SP500                        SP500     2024-10-21   2024-10-21
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2024-10-21   2024-10-21
# BAMLC0A0CM              BAMLC0A0CM     2024-10-21   2024-10-21
# ...                            ...            ...          ...
# DDDI12SMA156NWDB  DDDI12SMA156NWDB     2024-10-21   2024-10-21
# Q03069USQ605NNBR  Q03069USQ605NNBR     2024-10-21   2024-10-21
# CSHICPCZA156NRUG  CSHICPCZA156NRUG     2024-10-21   2024-10-21
# CSHXCPVEA156NRUG  CSHXCPVEA156NRUG     2024-10-21   2024-10-21
# CSHMCPNPA156NRUG  CSHMCPNPA156NRUG     2024-10-21   2024-10-21
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# CSUSHPINSA        S&P CoreLogic Case-Shiller U.S. National Home ...
# SP500                                                       S&P 500
# BAMLH0A0HYM2EY         ICE BofA US High Yield Index Effective Yield
# BAMLC0A0CM        ICE BofA US Corporate Index Option-Adjusted Sp...
# ...                                                             ...
# DDDI12SMA156NWDB  Private Credit by Deposit Money Banks and Othe...
# Q03069USQ605NNBR  Revenue Freight Tons Originated, Less Than Car...
# CSHICPCZA156NRUG  Share of Gross Capital Formation at Current Pu...
# CSHXCPVEA156NRUG  Share of Merchandise Exports at Current Purcha...
# CSHMCPNPA156NRUG  Share of Merchandise Imports at Current Purcha...
#
#                  observation_start observation_end     frequency  \
# series id
# BAMLH0A0HYM2            1996-12-31      2024-10-18  Daily, Close
# CSUSHPINSA              1987-01-01      2024-07-01       Monthly
# SP500                   2014-10-20      2024-10-18  Daily, Close
# BAMLH0A0HYM2EY          1996-12-31      2024-10-18  Daily, Close
# BAMLC0A0CM              1996-12-31      2024-10-18  Daily, Close
# ...                            ...             ...           ...
# DDDI12SMA156NWDB        2001-01-01      2020-01-01        Annual
# Q03069USQ605NNBR        1920-01-01      1943-07-01     Quarterly
# CSHICPCZA156NRUG        1990-01-01      2019-01-01        Annual
# CSHXCPVEA156NRUG        1950-01-01      2019-01-01        Annual
# CSHMCPNPA156NRUG        1960-01-01      2019-01-01        Annual
#
#                  frequency_short               units         units_short  \
# series id
# BAMLH0A0HYM2                   D             Percent                   %
# CSUSHPINSA                     M  Index Jan 2000=100  Index Jan 2000=100
# SP500                          D               Index               Index
# BAMLH0A0HYM2EY                 D             Percent                   %
# BAMLC0A0CM                     D             Percent                   %
# ...                          ...                 ...                 ...
# DDDI12SMA156NWDB               A             Percent                   %
# Q03069USQ605NNBR               Q   Thousands of Tons      Thous. Of Tons
# CSHICPCZA156NRUG               A             Percent                   %
# CSHXCPVEA156NRUG               A             Percent                   %
# CSHMCPNPA156NRUG               A             Percent                   %
#
#                       seasonal_adjustment seasonal_adjustment_short  \
# series id
# BAMLH0A0HYM2      Not Seasonally Adjusted                       NSA
# CSUSHPINSA        Not Seasonally Adjusted                       NSA
# SP500             Not Seasonally Adjusted                       NSA
# BAMLH0A0HYM2EY    Not Seasonally Adjusted                       NSA
# BAMLC0A0CM        Not Seasonally Adjusted                       NSA
# ...                                   ...                       ...
# DDDI12SMA156NWDB  Not Seasonally Adjusted                       NSA
# Q03069USQ605NNBR  Not Seasonally Adjusted                       NSA
# CSHICPCZA156NRUG  Not Seasonally Adjusted                       NSA
# CSHXCPVEA156NRUG  Not Seasonally Adjusted                       NSA
# CSHMCPNPA156NRUG  Not Seasonally Adjusted                       NSA
#
#                                last_updated popularity  \
# series id
# BAMLH0A0HYM2      2024-10-21 08:53:11-05:00         92
# CSUSHPINSA        2024-09-25 10:50:02-05:00         88
# SP500             2024-10-18 19:11:32-05:00         83
# BAMLH0A0HYM2EY    2024-10-21 08:53:14-05:00         82
# BAMLC0A0CM        2024-10-21 08:59:02-05:00         78
# ...                                     ...        ...
# DDDI12SMA156NWDB  2024-05-07 15:28:48-05:00          3
# Q03069USQ605NNBR  2012-08-16 14:05:10-05:00          3
# CSHICPCZA156NRUG  2021-11-08 13:36:33-06:00          3
# CSHXCPVEA156NRUG  2021-11-08 13:32:15-06:00          3
# CSHMCPNPA156NRUG  2021-11-08 13:33:11-06:00          3
#
#                                                               notes
# series id
# BAMLH0A0HYM2      The ICE BofA Option-Adjusted Spreads (OASs) ar...
# CSUSHPINSA        For more information regarding the index, plea...
# SP500             The observations for the S&P 500 represent the...
# BAMLH0A0HYM2EY    This data represents the effective yield of th...
# BAMLC0A0CM        The ICE BofA Option-Adjusted Spreads (OASs) ar...
# ...                                                             ...
# DDDI12SMA156NWDB  Private credit by deposit money banks and othe...
# Q03069USQ605NNBR  Source: Interstate Commerce Commission, Data F...
# CSHICPCZA156NRUG  Source ID: csh_i  When using these data in you...
# CSHXCPVEA156NRUG  Source ID: csh_x  When using these data in you...
# CSHMCPNPA156NRUG  Source ID: csh_m  When using these data in you...
#
# [1000 rows x 15 columns]

# %% [markdown]
# # 3. Pull Raw Data and Plot

# %%
sp500 = fred.get_series('SP500')

# %%
sp500.plot(figsize=(10, 5), title="s&p 500", lw=2)
# Out:
# <Axes: title={'center': 's&p 500'}>

# %% [markdown]
# # 4. pull and join Multiple Data Series

# %%
unemp_df = fred.search('unemployment rate state', filter=('frequency', 'Monthly'))
unemp_df = unemp_df.query('seasonal_adjustment == "Seasonally Adjusted" and units == "Percent"')
unemp_df = unemp_df.loc[unemp_df['title'].str.contains('Unemployment Rate')]

# %%
all_results = []
for i in unemp_df.index:
    result = fred.get_series(i)
    result = result.to_frame(name=i)
    all_results.append(result)
# unemp_df = pd.concat(all_results, axis=1).drop(['M08311USM156SNBR', 'DSUR'], axis=1)

# %%
unemp_results = pd.concat(all_results, axis=1).drop(['M08311USM156SNBR'], axis=1)

# %%
unemp_states = unemp_results.drop('UNRATE', axis=1)

# %%
unemp_states
# Out:
#             LNS14000006  CAUR  TXUR  M0892AUSM156SNBR  LNS14000024  \
# 1929-04-01          NaN   NaN   NaN              0.69          NaN
# 1929-05-01          NaN   NaN   NaN              1.65          NaN
# 1929-06-01          NaN   NaN   NaN              2.06          NaN
# 1929-07-01          NaN   NaN   NaN              0.79          NaN
# 1929-08-01          NaN   NaN   NaN              0.04          NaN
# ...                 ...   ...   ...               ...          ...
# 2024-05-01          6.1   5.2   4.0               NaN          3.6
# 2024-06-01          6.3   5.2   4.0               NaN          3.7
# 2024-07-01          6.3   5.2   4.1               NaN          3.9
# 2024-08-01          6.1   5.3   4.1               NaN          3.8
# 2024-09-01          5.7   NaN   NaN               NaN          3.6
#
#             LNS14000031  M0892BUSM156SNBR  NYUR  U2RATE  FLUR  ...  \
# 1929-04-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-05-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-06-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-07-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-08-01          NaN               NaN   NaN     NaN   NaN  ...
# ...                 ...               ...   ...     ...   ...  ...
# 2024-05-01          6.4               NaN   4.2     1.9   3.3  ...
# 2024-06-01          6.1               NaN   4.2     1.9   3.3  ...
# 2024-07-01          6.6               NaN   4.3     2.1   3.3  ...
# 2024-08-01          5.9               NaN   4.4     2.0   3.3  ...
# 2024-09-01          5.1               NaN   NaN     1.9   NaN  ...
#
#             LNS14000025  LNS14000061  CNERUR  LRUNTTTTUSM156S  CWSTUR  CNEWUR  \
# 1929-04-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-05-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-06-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-07-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-08-01          NaN          NaN     NaN              NaN     NaN     NaN
# ...                 ...          ...     ...              ...     ...     ...
# 2024-05-01          3.8          3.5     3.9              4.0     4.6     3.4
# 2024-06-01          3.8          3.5     3.8              4.1     4.5     3.3
# 2024-07-01          4.0          3.7     3.9              4.3     4.6     3.4
# 2024-08-01          4.0          3.6     4.0              4.2     4.6     3.5
# 2024-09-01          3.7          3.5     NaN              4.1     NaN     NaN
#
#             LNS14000026  LNS14000048  LNS14000089  LNS14000150
# 1929-04-01          NaN          NaN          NaN          NaN
# 1929-05-01          NaN          NaN          NaN          NaN
# 1929-06-01          NaN          NaN          NaN          NaN
# 1929-07-01          NaN          NaN          NaN          NaN
# 1929-08-01          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...
# 2024-05-01          3.4          3.2          4.1          1.9
# 2024-06-01          3.7          3.3          4.4          1.9
# 2024-07-01          3.8          3.5          4.8          2.1
# 2024-08-01          3.7          3.4          4.5          2.1
# 2024-09-01          3.6          3.3          4.1          2.1
#
# [1134 rows x 96 columns]

# %%
px.line(unemp_states)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_107.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# print(unemp_states.head())

# %% [markdown]
# ## Pull April 2020 Unemployment Rate Per State

# %%
unemp_states
# Out:
#             LNS14000006  CAUR  TXUR  M0892AUSM156SNBR  LNS14000024  \
# 1929-04-01          NaN   NaN   NaN              0.69          NaN
# 1929-05-01          NaN   NaN   NaN              1.65          NaN
# 1929-06-01          NaN   NaN   NaN              2.06          NaN
# 1929-07-01          NaN   NaN   NaN              0.79          NaN
# 1929-08-01          NaN   NaN   NaN              0.04          NaN
# ...                 ...   ...   ...               ...          ...
# 2024-05-01          6.1   5.2   4.0               NaN          3.6
# 2024-06-01          6.3   5.2   4.0               NaN          3.7
# 2024-07-01          6.3   5.2   4.1               NaN          3.9
# 2024-08-01          6.1   5.3   4.1               NaN          3.8
# 2024-09-01          5.7   NaN   NaN               NaN          3.6
#
#             LNS14000031  M0892BUSM156SNBR  NYUR  U2RATE  FLUR  ...  \
# 1929-04-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-05-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-06-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-07-01          NaN               NaN   NaN     NaN   NaN  ...
# 1929-08-01          NaN               NaN   NaN     NaN   NaN  ...
# ...                 ...               ...   ...     ...   ...  ...
# 2024-05-01          6.4               NaN   4.2     1.9   3.3  ...
# 2024-06-01          6.1               NaN   4.2     1.9   3.3  ...
# 2024-07-01          6.6               NaN   4.3     2.1   3.3  ...
# 2024-08-01          5.9               NaN   4.4     2.0   3.3  ...
# 2024-09-01          5.1               NaN   NaN     1.9   NaN  ...
#
#             LNS14000025  LNS14000061  CNERUR  LRUNTTTTUSM156S  CWSTUR  CNEWUR  \
# 1929-04-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-05-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-06-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-07-01          NaN          NaN     NaN              NaN     NaN     NaN
# 1929-08-01          NaN          NaN     NaN              NaN     NaN     NaN
# ...                 ...          ...     ...              ...     ...     ...
# 2024-05-01          3.8          3.5     3.9              4.0     4.6     3.4
# 2024-06-01          3.8          3.5     3.8              4.1     4.5     3.3
# 2024-07-01          4.0          3.7     3.9              4.3     4.6     3.4
# 2024-08-01          4.0          3.6     4.0              4.2     4.6     3.5
# 2024-09-01          3.7          3.5     NaN              4.1     NaN     NaN
#
#             LNS14000026  LNS14000048  LNS14000089  LNS14000150
# 1929-04-01          NaN          NaN          NaN          NaN
# 1929-05-01          NaN          NaN          NaN          NaN
# 1929-06-01          NaN          NaN          NaN          NaN
# 1929-07-01          NaN          NaN          NaN          NaN
# 1929-08-01          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...
# 2024-05-01          3.4          3.2          4.1          1.9
# 2024-06-01          3.7          3.3          4.4          1.9
# 2024-07-01          3.8          3.5          4.8          2.1
# 2024-08-01          3.7          3.4          4.5          2.1
# 2024-09-01          3.6          3.3          4.1          2.1
#
# [1134 rows x 96 columns]

# %%
ax = unemp_states.loc[unemp_states.index == '2020-04-01'].T \
    .sort_values('2020-04-01') \
    .plot(kind='bar', figsize=(10, 5), title='unemployment rate by state April 2020')

ax.legend().remove()
plt.show()

# %%
id_to_states = unemp_df['title'].str.replace('Unemployment rate in', '').to_dict()

# %%
unemp_states.columns = [id_to_states[i] for i in unemp_states.columns]

# %%
unemp_states
# Out:
#             Unemployment Rate - Black or African American  \
# 1929-04-01                                            NaN
# 1929-05-01                                            NaN
# 1929-06-01                                            NaN
# 1929-07-01                                            NaN
# 1929-08-01                                            NaN
# ...                                                   ...
# 2024-05-01                                            6.1
# 2024-06-01                                            6.3
# 2024-07-01                                            6.3
# 2024-08-01                                            6.1
# 2024-09-01                                            5.7
#
#             Unemployment Rate in California  Unemployment Rate in Texas  \
# 1929-04-01                              NaN                         NaN
# 1929-05-01                              NaN                         NaN
# 1929-06-01                              NaN                         NaN
# 1929-07-01                              NaN                         NaN
# 1929-08-01                              NaN                         NaN
# ...                                     ...                         ...
# 2024-05-01                              5.2                         4.0
# 2024-06-01                              5.2                         4.0
# 2024-07-01                              5.2                         4.1
# 2024-08-01                              5.3                         4.1
# 2024-09-01                              NaN                         NaN
#
#             Unemployment Rate for United States  \
# 1929-04-01                                 0.69
# 1929-05-01                                 1.65
# 1929-06-01                                 2.06
# 1929-07-01                                 0.79
# 1929-08-01                                 0.04
# ...                                         ...
# 2024-05-01                                  NaN
# 2024-06-01                                  NaN
# 2024-07-01                                  NaN
# 2024-08-01                                  NaN
# 2024-09-01                                  NaN
#
#             Unemployment Rate - 20 Yrs. & over  \
# 1929-04-01                                 NaN
# 1929-05-01                                 NaN
# 1929-06-01                                 NaN
# 1929-07-01                                 NaN
# 1929-08-01                                 NaN
# ...                                        ...
# 2024-05-01                                 3.6
# 2024-06-01                                 3.7
# 2024-07-01                                 3.9
# 2024-08-01                                 3.8
# 2024-09-01                                 3.6
#
#             Unemployment Rate - 20 Yrs. & over, Black or African American Men  \
# 1929-04-01                                                NaN
# 1929-05-01                                                NaN
# 1929-06-01                                                NaN
# 1929-07-01                                                NaN
# 1929-08-01                                                NaN
# ...                                                       ...
# 2024-05-01                                                6.4
# 2024-06-01                                                6.1
# 2024-07-01                                                6.6
# 2024-08-01                                                5.9
# 2024-09-01                                                5.1
#
#             Unemployment Rate for United States  \
# 1929-04-01                                  NaN
# 1929-05-01                                  NaN
# 1929-06-01                                  NaN
# 1929-07-01                                  NaN
# 1929-08-01                                  NaN
# ...                                         ...
# 2024-05-01                                  NaN
# 2024-06-01                                  NaN
# 2024-07-01                                  NaN
# 2024-08-01                                  NaN
# 2024-09-01                                  NaN
#
#             Unemployment Rate in New York  \
# 1929-04-01                            NaN
# 1929-05-01                            NaN
# 1929-06-01                            NaN
# 1929-07-01                            NaN
# 1929-08-01                            NaN
# ...                                   ...
# 2024-05-01                            4.2
# 2024-06-01                            4.2
# 2024-07-01                            4.3
# 2024-08-01                            4.4
# 2024-09-01                            NaN
#
#             Unemployment Rate - Job Losers (U-2)  \
# 1929-04-01                                   NaN
# 1929-05-01                                   NaN
# 1929-06-01                                   NaN
# 1929-07-01                                   NaN
# 1929-08-01                                   NaN
# ...                                          ...
# 2024-05-01                                   1.9
# 2024-06-01                                   1.9
# 2024-07-01                                   2.1
# 2024-08-01                                   2.0
# 2024-09-01                                   1.9
#
#             Unemployment Rate in Florida  ...  \
# 1929-04-01                           NaN  ...
# 1929-05-01                           NaN  ...
# 1929-06-01                           NaN  ...
# 1929-07-01                           NaN  ...
# 1929-08-01                           NaN  ...
# ...                                  ...  ...
# 2024-05-01                           3.3  ...
# 2024-06-01                           3.3  ...
# 2024-07-01                           3.3  ...
# 2024-08-01                           3.3  ...
# 2024-09-01                           NaN  ...
#
#             Unemployment Rate - 20 Yrs. & over, Men  \
# 1929-04-01                                      NaN
# 1929-05-01                                      NaN
# 1929-06-01                                      NaN
# 1929-07-01                                      NaN
# 1929-08-01                                      NaN
# ...                                             ...
# 2024-05-01                                      3.8
# 2024-06-01                                      3.8
# 2024-07-01                                      4.0
# 2024-08-01                                      4.0
# 2024-09-01                                      3.7
#
#             Unemployment Rate - 25-54 Yrs., Men  \
# 1929-04-01                                  NaN
# 1929-05-01                                  NaN
# 1929-06-01                                  NaN
# 1929-07-01                                  NaN
# 1929-08-01                                  NaN
# ...                                         ...
# 2024-05-01                                  3.5
# 2024-06-01                                  3.5
# 2024-07-01                                  3.7
# 2024-08-01                                  3.6
# 2024-09-01                                  3.5
#
#             Unemployment Rate in Northeast Census Region  \
# 1929-04-01                                           NaN
# 1929-05-01                                           NaN
# 1929-06-01                                           NaN
# 1929-07-01                                           NaN
# 1929-08-01                                           NaN
# ...                                                  ...
# 2024-05-01                                           3.9
# 2024-06-01                                           3.8
# 2024-07-01                                           3.9
# 2024-08-01                                           4.0
# 2024-09-01                                           NaN
#
#             Infra-Annual Labor Statistics: Unemployment Rate Total: 15 Years or over for United States  \
# 1929-04-01                                                NaN
# 1929-05-01                                                NaN
# 1929-06-01                                                NaN
# 1929-07-01                                                NaN
# 1929-08-01                                                NaN
# ...                                                       ...
# 2024-05-01                                                4.0
# 2024-06-01                                                4.1
# 2024-07-01                                                4.3
# 2024-08-01                                                4.2
# 2024-09-01                                                4.1
#
#             Unemployment Rate in West Census Region  \
# 1929-04-01                                      NaN
# 1929-05-01                                      NaN
# 1929-06-01                                      NaN
# 1929-07-01                                      NaN
# 1929-08-01                                      NaN
# ...                                             ...
# 2024-05-01                                      4.6
# 2024-06-01                                      4.5
# 2024-07-01                                      4.6
# 2024-08-01                                      4.6
# 2024-09-01                                      NaN
#
#             Unemployment Rate in New England Census Division  \
# 1929-04-01                                               NaN
# 1929-05-01                                               NaN
# 1929-06-01                                               NaN
# 1929-07-01                                               NaN
# 1929-08-01                                               NaN
# ...                                                      ...
# 2024-05-01                                               3.4
# 2024-06-01                                               3.3
# 2024-07-01                                               3.4
# 2024-08-01                                               3.5
# 2024-09-01                                               NaN
#
#             Unemployment Rate - 20 Yrs. & over, Women  \
# 1929-04-01                                        NaN
# 1929-05-01                                        NaN
# 1929-06-01                                        NaN
# 1929-07-01                                        NaN
# 1929-08-01                                        NaN
# ...                                               ...
# 2024-05-01                                        3.4
# 2024-06-01                                        3.7
# 2024-07-01                                        3.8
# 2024-08-01                                        3.7
# 2024-09-01                                        3.6
#
#             Unemployment Rate - 25 Yrs. & over  \
# 1929-04-01                                 NaN
# 1929-05-01                                 NaN
# 1929-06-01                                 NaN
# 1929-07-01                                 NaN
# 1929-08-01                                 NaN
# ...                                        ...
# 2024-05-01                                 3.2
# 2024-06-01                                 3.3
# 2024-07-01                                 3.5
# 2024-08-01                                 3.4
# 2024-09-01                                 3.3
#
#             Unemployment Rate - 25-34 Yrs.  Unemployment Rate - Married Men
# 1929-04-01                             NaN                              NaN
# 1929-05-01                             NaN                              NaN
# 1929-06-01                             NaN                              NaN
# 1929-07-01                             NaN                              NaN
# 1929-08-01                             NaN                              NaN
# ...                                    ...                              ...
# 2024-05-01                             4.1                              1.9
# 2024-06-01                             4.4                              1.9
# 2024-07-01                             4.8                              2.1
# 2024-08-01                             4.5                              2.1
# 2024-09-01                             4.1                              2.1
#
# [1134 rows x 96 columns]
